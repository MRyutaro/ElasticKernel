# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# hello      str     world

# %%
hello = "world"

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# hello      str     world
