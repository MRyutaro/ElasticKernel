# %%
# %whos
# Out:
# Interactive namespace is empty.

# %%
import time

start_time = time.perf_counter()

def fibonacci(n):
    if n <= 1:
        return n
    return fibonacci(n-1) + fibonacci(n-2)

# 計算時間が長くなるように大きな値で実行
result = fibonacci(40)

end_time = time.perf_counter()
elapsed_time = end_time - start_time

print(f"fibonacci(40) = {result}")
print(f"実行時間: {elapsed_time:.4f}秒")
# Out:
# fibonacci(40) = 102334155
# 実行時間: 17.7671秒

# %%
# %whos
# Out:
# Variable       Type        Data/Info
# ------------------------------------
# elapsed_time   float       17.76709222793579
# end_time       float       1766816007.1908295
# fibonacci      function    <function fibonacci at 0x76a0afaf6a20>
# result         int         102334155
# start_time     float       1766815989.4237373
# time           module      <module 'time' (built-in)>
