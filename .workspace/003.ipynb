# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# np         module     <module 'numpy' from '/tm<...>kages/numpy/__init__.py'>
# x          ndarray    134217728: 134217728 elems, type `int64`, 1073741824 bytes (1024.0 Mb)

# %%
import numpy as np

# %%
x = np.arange(2**27)

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# np         module     <module 'numpy' from '/tm<...>kages/numpy/__init__.py'>
# x          ndarray    134217728: 134217728 elems, type `int64`, 1073741824 bytes (1024.0 Mb)
